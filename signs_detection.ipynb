# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from PIL import Image
import os
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

# %%
"""Storing data and labels in the list"""
data = []  # Empty list of data
labels = []  # Empty list of labels
# classes = 43

# %%
"""
Saving our model after training with Numpy
It can be used for future purposes
There is no need to go through all steps from beginning, use this
"""
np.save('./Data/Future_Data', data)
np.save('./Data/Future_Data', labels)

# %%
"""Loading Numpy Future Data"""
#data = np.load('./Data/Future_Data')
#labels = np.load('./Data/Future_Data')
# Out:
# 'Loading Numpy Future Data'

# %%
"""Locating working directory and printing it out"""
file_path = os.getcwd()
# print(file_path)
# C:\Users\SMXaS\PycharmProjects\signs_recognition

# %%
"""
Looping through 43 classes
Opening data - train file
Declaring 'images' as faster way to open train file
---------------------------------------------------
Looping through settings of images
Opening images
Resizing the pictures
Modifying the list with append for data and labels
Raising the exception if there was any errors
"""
for pictures in range(43):
    data_path = os.path.join(file_path, 'Data/Train', str(pictures))
    images = os.listdir(data_path)
    for setting in images:
        try:
            image = Image.open(data_path + '\\' + setting)
            image = image.resize((30, 30))
            image = np.array(image)
            data.append(image)
            labels.append(pictures)
        except Exception as error:
            print(error)

# %%
"""Making data and labels list to be numpy arrays"""
data = np.array(data)
labels = np.array(labels)

# %%
"""Printing out the shape of data and labels"""
# print(data.shape, labels.shape)
# Out:
# 'Printing out the shape of data and labels'

# %%
"""Preparing testing, training and setting up the parameters"""
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=0)

# %%
"""Converting classes to encode integer data"""
y_train = to_categorical(y_train, 43)
y_test = to_categorical(y_test, 43)

# %%
"""Preparing the model
Model has parameters from KERAS API
Activation layers, filters, size, shape, rate which can be changed
"""
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(5, 5), activation='relu', input_shape=X_train.shape[1:]))
model.add(Conv2D(filters=32, kernel_size=(5, 5), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(43, activation='softmax'))

# %%
"""Compiling the model"""
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
"""Setting up the epochs and history of each compile"""
epochs = 20
history = model.fit(X_train, y_train, batch_size=32, epochs=epochs, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 981/981 [==============================] - 98s 100ms/step - loss: 2.3617 - accuracy: 0.3850 - val_loss: 1.0576 - val_accuracy: 0.7196
# Epoch 2/20
# 981/981 [==============================] - 97s 99ms/step - loss: 0.9663 - accuracy: 0.7086 - val_loss: 0.3184 - val_accuracy: 0.9088
# Epoch 3/20
# 981/981 [==============================] - 98s 100ms/step - loss: 0.5243 - accuracy: 0.8428 - val_loss: 0.2028 - val_accuracy: 0.9449
# Epoch 4/20
# 981/981 [==============================] - 97s 99ms/step - loss: 0.3856 - accuracy: 0.8855 - val_loss: 0.1467 - val_accuracy: 0.9592
# Epoch 5/20
# 981/981 [==============================] - 97s 99ms/step - loss: 0.3242 - accuracy: 0.9065 - val_loss: 0.0984 - val_accuracy: 0.9719
# Epoch 6/20
# 981/981 [==============================] - 97s 99ms/step - loss: 0.2917 - accuracy: 0.9172 - val_loss: 0.1134 - val_accuracy: 0.9663
# Epoch 7/20
# 981/981 [==============================] - 97s 99ms/step - loss: 0.2787 - accuracy: 0.9227 - val_loss: 0.1012 - val_accuracy: 0.9708
# Epoch 8/20
# 981/981 [==============================] - 96s 98ms/step - loss: 0.2406 - accuracy: 0.9331 - val_loss: 0.0757 - val_accuracy: 0.9786
# Epoch 9/20
# 981/981 [==============================] - 98s 100ms/step - loss: 0.2531 - accuracy: 0.9291 - val_loss: 0.0859 - val_accuracy: 0.9763
# Epoch 10/20
# 981/981 [==============================] - 97s 99ms/step - loss: 0.2479 - accuracy: 0.9321 - val_loss: 0.1078 - val_accuracy: 0.9697
# Epoch 11/20
# 981/981 [==============================] - 97s 99ms/step - loss: 0.2498 - accuracy: 0.9321 - val_loss: 0.0791 - val_accuracy: 0.9772
# Epoch 12/20
# 981/981 [==============================] - 96s 98ms/step - loss: 0.2164 - accuracy: 0.9407 - val_loss: 0.0501 - val_accuracy: 0.9862
# Epoch 13/20
# 981/981 [==============================] - 97s 98ms/step - loss: 0.2341 - accuracy: 0.9389 - val_loss: 0.0727 - val_accuracy: 0.9802
# Epoch 14/20
# 981/981 [==============================] - 96s 98ms/step - loss: 0.2297 - accuracy: 0.9391 - val_loss: 0.0568 - val_accuracy: 0.9842
# Epoch 15/20
# 981/981 [==============================] - 97s 99ms/step - loss: 0.2530 - accuracy: 0.9331 - val_loss: 0.0757 - val_accuracy: 0.9795
# Epoch 16/20
# 981/981 [==============================] - 97s 99ms/step - loss: 0.2353 - accuracy: 0.9382 - val_loss: 0.0637 - val_accuracy: 0.9834
# Epoch 17/20
# 981/981 [==============================] - 97s 99ms/step - loss: 0.2116 - accuracy: 0.9443 - val_loss: 0.0951 - val_accuracy: 0.9739
# Epoch 18/20
# 981/981 [==============================] - 97s 98ms/step - loss: 0.2220 - accuracy: 0.9436 - val_loss: 0.0890 - val_accuracy: 0.9731
# Epoch 19/20
# 981/981 [==============================] - 96s 98ms/step - loss: 0.2291 - accuracy: 0.9412 - val_loss: 0.0477 - val_accuracy: 0.9870
# Epoch 20/20
# 981/981 [==============================] - 96s 98ms/step - loss: 0.2369 - accuracy: 0.9400 - val_loss: 0.0833 - val_accuracy: 0.9782

# %%
"""Reading csv file..."""
def test_image(testcsv):
    y_test = pd.read_csv(testcsv)
    label = y_test["class_id"].values
    imgs = y_test["name"].values
    data = []
    for img in imgs:
        image = Image.open(img)
        image = image.resize((30, 30))
        data.append(np.array(image))
    X_test = np.array(data)
    return X_test, label

# %%
X_test, label = test_image('Test.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-853d3009c7c6> in <module>
# ----> 1 X_test, label = test_image('Test.csv')
#
# <ipython-input-32-dfb20d61444e> in test_image(testcsv)
#       1 """Reading csv file..."""
#       2 def test_image(testcsv):
# ----> 3     y_test = pd.read_csv(testcsv)
#       4     label = y_test["class_id"].values
#       5     imgs = y_test["name"].values
#
# c:\users\smxas\anaconda3\envs\signs_recognition\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# c:\users\smxas\anaconda3\envs\signs_recognition\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# c:\users\smxas\anaconda3\envs\signs_recognition\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# c:\users\smxas\anaconda3\envs\signs_recognition\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# c:\users\smxas\anaconda3\envs\signs_recognition\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    2008         kwds["usecols"] = self.usecols
#    2009
# -> 2010         self._reader = parsers.TextReader(src, **kwds)
#    2011         self.unnamed_cols = self._reader.unnamed_cols
#    2012
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Test.csv'

# %%
Y_predict = model.predict_classes(X_test)
# Out:
# WARNING:tensorflow:From <ipython-input-34-9af354123ecf>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).

# %%
print(accuracy_score(label, Y_predict))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-b61b3aa81875> in <module>
# ----> 1 print(accuracy_score(label, Y_predict))
#
# NameError: name 'label' is not defined

# %%
model.save('./Data/Future_Data)
# Out:
#   File "<ipython-input-36-bc85d4ff3943>", line 1
#     model.save('./Data/Future_Data)
#                                    ^
# SyntaxError: EOL while scanning string literal

# %%
classes = { 0:'Speed limit (20km/h)',
            1:'Speed limit (30km/h)', 
            2:'Speed limit (50km/h)', 
            3:'Speed limit (60km/h)', 
            4:'Speed limit (70km/h)', 
            5:'Speed limit (80km/h)', 
            6:'End of speed limit (80km/h)', 
            7:'Speed limit (100km/h)', 
            8:'Speed limit (120km/h)', 
            9:'No passing', 
            10:'No passing veh over 3.5 tons', 
            11:'Right-of-way at intersection', 
            12:'Priority road', 
            13:'Yield', 
            14:'Stop', 
            15:'No vehicles', 
            16:'Veh > 3.5 tons prohibited', 
            17:'No entry', 
            18:'General caution', 
            19:'Dangerous curve left', 
            20:'Dangerous curve right', 
            21:'Double curve', 
            22:'Bumpy road', 
            23:'Slippery road', 
            24:'Road narrows on the right', 
            25:'Road work', 
            26:'Traffic signals', 
            27:'Pedestrians', 
            28:'Children crossing', 
            29:'Bicycles crossing', 
            30:'Beware of ice/snow',
            31:'Wild animals crossing', 
            32:'End speed + passing limits', 
            33:'Turn right ahead', 
            34:'Turn left ahead', 
            35:'Ahead only', 
            36:'Go straight or right', 
            37:'Go straight or left', 
            38:'Keep right', 
            39:'Keep left', 
            40:'Roundabout mandatory', 
            41:'End of no passing', 
            42:'End no passing veh > 3.5 tons' }

# %%
def test_img(img):
    data = []
    image = Image.open(img)
    image = image.resize((30, 30))
    data.append(np.array(image))
    X_test = np.array(data)
    Y_predict = model.predict_classes(X_test)
    return image, Y_predict

# %%
plot, prediction = test_img(r'C:\Users\SMXaS\PycharmProjects\signs_recognition\Data\Test\00000.png')
s = [str(i) for i in prediction]
a = int("".join(s))
print("Predicted: ", data_csv[a])
plt.imshow(plot)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-306c4f1bf243> in <module>
#       2 s = [str(i) for i in prediction]
#       3 a = int("".join(s))
# ----> 4 print("Predicted: ", data_csv[a])
#       5 plt.imshow(plot)
#       6 plt.show()
#
# NameError: name 'data_csv' is not defined
